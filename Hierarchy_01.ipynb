# %%
import numpy as np
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# Example dataset
X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])

# Perform hierarchical clustering with different linkages
linkages = ['ward', 'single', 'complete', 'average']
for linkage in linkages:
    Z = sch.linkage(X, method=linkage)
    plt.figure(figsize=(10, 7))
    sch.dendrogram(Z)
    plt.title(f'Dendrogram with {linkage.capitalize()} Linkage')
    plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# Example dataset
X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])

# Agglomerative Clustering with Ward's linkage
model = AgglomerativeClustering(n_clusters=2, linkage='ward')
labels = model.fit_predict(X)

print("Cluster Labels:", labels)
# Out:
# Cluster Labels: [1 1 1 0 0 0]

# %%
from sklearn.cluster import di
import numpy as np

# Example dataset
X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])

# Agglomerative Clustering with Ward's linkage
model = AgglomerativeClustering(n_clusters=2, linkage='ward')
labels = model.fit_predict(X)

print("Cluster Labels:", labels)
